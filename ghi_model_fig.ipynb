# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model, ensemble, svm, tree, neural_network

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %%
result = {}

# %%
# hhids = [26, 59]
hhids = [26, 59, 77, 86, 93, 94, 101, 114, 115, 160, 171, 187]

for hhid in hhids: 
    result[hhid] = []
    print('Start :: Process on household {}...'.format(hhid))
    df = pd.read_csv('./data/added_hhdata_{}.csv'.format(hhid), index_col=0)
    st = []
    ct = 0
    for idx, row in df.iterrows():
        if row.GH < 2000 and row.GH > -1000:
            st.append(row)
        else:
            ct += 1

    # print(ct)
    df = pd.DataFrame(data=st, columns=df.columns)
    used_feature = ['localhour', 'temperature', 'cloud_cover', 'wind_speed','GH','GH_month','GH_week']
    ordered_features = ['GH', 'localhour', 'temperature', 'cloud_cover','wind_speed','GH_month','GH_week']
    lh = df.apply(lambda x: int(x.localhour[11:13]), axis=1)
    df.localhour = lh

    Y = list(df.GH)[1:]
    Y.append(df.GH.iloc[0])
    Y = np.array(Y)

    X = df[used_feature]
    X = np.array(X)
    X.shape

    temp_df = pd.DataFrame(data=X, columns=used_feature)
    temp_df = temp_df[ordered_features]
    temp_df['y_GH'] = Y
    values = temp_df.values

    # normalize features
    scaler = MinMaxScaler()
    y_gt = values[:,-1:]
    scaled = scaler.fit_transform(values)
    values = scaled

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                        test_size=0.10,
                                                        random_state=666)


    classifiers = [
        linear_model.Ridge(alpha=1.0, random_state=0),
        linear_model.Lasso(alpha=0.55, random_state=0),
        linear_model.BayesianRidge(alpha_1=1e-06, alpha_2=1e-06),
        linear_model.LassoLars(alpha=0.55),
        linear_model.LinearRegression(),
        ensemble.RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
           max_features='sqrt', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
           oob_score=False, random_state=0, verbose=0, warm_start=False),
        tree.DecisionTreeRegressor(),
        neural_network.MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(50, 50), learning_rate='constant',
       learning_rate_init=0.001, max_iter=200, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
       solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
       warm_start=False)
    ]


    print('Start :: Find the best model for this household...')
    for clf in classifiers:
        clf.fit(X_train, Y_train)
        print(clf)
        yhat = clf.predict(X_test)
        scores = cross_val_score(clf, X_train, Y_train)
        rmse = np.sqrt(mean_squared_error(Y_test, yhat))
        mae = mean_absolute_error(Y_test, yhat)
        print('RMSE =>', rmse)
        print('MAE =>', mae)
        print('CV Score =>', scores)
        model_dict = {
            'name': clf.__class__.__name__,
            'rmse': rmse,
            'mae': mae,
        }
        result[hhid].append(model_dict)
        print('')
# Out:
# Start :: Process on household 26...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 185.566940025
# MAE => 81.6551178448
# CV Score => [ 0.6449401   0.63433041  0.67954161]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 59...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 188.270774088
# MAE => 82.0035502957
# CV Score => [ 0.63754318  0.6520259   0.69639644]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 77...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 191.44967332
# MAE => 84.932267811
# CV Score => [ 0.63926152  0.63926654  0.69496291]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 86...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 183.751812486
# MAE => 80.6697909967
# CV Score => [ 0.63647133  0.65325536  0.67408135]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 93...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 176.496617552
# MAE => 78.3200972644
# CV Score => [ 0.62498896  0.64053779  0.67409485]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 94...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 194.003291672
# MAE => 113.956910374
# CV Score => [ 0.68011656  0.65173759  0.66775197]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 193.967486358
# MAE => 113.925401678
# CV Score => [ 0.68019821  0.65166887  0.66764518]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 193.980034163
# MAE => 114.036831647
# CV Score => [ 0.67977166  0.65048136  0.66679987]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 201.810061077
# MAE => 138.027281006
# CV Score => [ 0.66031739  0.62942594  0.63974785]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 194.00359086
# MAE => 113.957065381
# CV Score => [ 0.68011514  0.65173776  0.66775296]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 143.925222004
# MAE => 67.0012234756
# CV Score => [ 0.82251939  0.78126727  0.80057324]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 189.924888111
# MAE => 81.5896823753
# CV Score => [ 0.62825696  0.59151885  0.61956069]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 183.367529786
# MAE => 106.614548969
# CV Score => [ 0.72170091  0.67615909  0.69576235]
#
# Start :: Process on household 101...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 178.911548344
# MAE => 80.081348602
# CV Score => [ 0.6451374   0.63651675  0.68697941]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 114...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 182.877825486
# MAE => 79.4439078192
# CV Score => [ 0.61614712  0.65712198  0.67457914]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 115...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 164.078796136
# MAE => 110.220448037
# CV Score => [ 0.72000096  0.74438218  0.76796835]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 164.156574707
# MAE => 110.309865259
# CV Score => [ 0.72002344  0.74456389  0.7676834 ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 164.500877145
# MAE => 110.674434244
# CV Score => [ 0.71974781  0.74462613  0.76692551]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 172.015062309
# MAE => 126.098951948
# CV Score => [ 0.70667425  0.71916728  0.73070063]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 164.078226233
# MAE => 110.219736992
# CV Score => [ 0.72000043  0.74437842  0.76797057]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 132.06264578
# MAE => 65.5888754383
# CV Score => [ 0.81805528  0.85109296  0.85175919]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 179.508121667
# MAE => 82.4312487475
# CV Score => [ 0.69661247  0.68638358  0.75413858]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 143.235458928
# MAE => 78.5496766829
# CV Score => [ 0.76052107  0.76924874  0.77462444]
#
# Start :: Process on household 160...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 87.5356727543
# MAE => 71.2083900501
# CV Score => [ 0.88177716  0.89405322  0.81132363]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 87.4849774457
# MAE => 71.2046744877
# CV Score => [ 0.88183687  0.89381018  0.8108983 ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 88.9086185148
# MAE => 70.960523275
# CV Score => [ 0.87106324  0.88464495  0.80982158]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 88.4053679735
# MAE => 68.7197699275
# CV Score => [ 0.87195587  0.883414    0.82109874]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 87.5585936147
# MAE => 71.1963562933
# CV Score => [ 0.88209504  0.89495102  0.80920531]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 56.4536947487
# MAE => 33.6635620833
# CV Score => [ 0.92995129  0.94716532  0.89220748]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 127.149010848
# MAE => 41.5562171667
# CV Score => [ 0.87544914  0.90326421  0.86188619]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 149.438219506
# MAE => 98.1111964955
# CV Score => [ 0.76572319  0.8121295   0.80158068]
#
# Start :: Process on household 171...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 188.014318545
# MAE => 83.1548406421
# CV Score => [ 0.61835249  0.64776915  0.67034448]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]
#
# Start :: Process on household 187...
# Start :: Find the best model for this household...
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=0, solver='auto', tol=0.001)
# RMSE => 157.807596312
# MAE => 102.236546121
# CV Score => [ 0.66918512  0.61617114  0.69707543]
#
# Lasso(alpha=0.55, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=0,
#    selection='cyclic', tol=0.0001, warm_start=False)
# RMSE => 157.775520369
# MAE => 102.145127215
# CV Score => [ 0.66901279  0.61646565  0.69683   ]
#
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# RMSE => 157.818960394
# MAE => 102.091509335
# CV Score => [ 0.66819881  0.61693413  0.69559507]
#
# LassoLars(alpha=0.55, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      positive=False, precompute='auto', verbose=False)
# RMSE => 169.291042323
# MAE => 123.384916237
# CV Score => [ 0.64886215  0.60575918  0.6597208 ]
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# RMSE => 157.80783779
# MAE => 102.237228361
# CV Score => [ 0.6691867   0.61616562  0.69707736]
#
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)
# RMSE => 121.981909224
# MAE => 59.8490761166
# CV Score => [ 0.79059005  0.78451051  0.81045498]
#
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# RMSE => 179.325972293
# MAE => 79.8896656283
# CV Score => [ 0.63331686  0.6563605   0.69553804]
#
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=0, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# RMSE => 154.121464694
# MAE => 90.6912025186
# CV Score => [ 0.6697867   0.65486736  0.70284391]

# %%
final = []
for k, v in result.items():
    for i in result[k]:
        final.append([str(k), i['name'], i['rmse'], i['mae']])
col = ['household_id', 'alg', 'RMSE', 'MAE']
final = pd.DataFrame(data=final, columns=col)
final.to_csv('GHI.csv')

# %%
final
# Out:
#    household_id                    alg        RMSE         MAE
# 0            26                  Ridge  157.807596  102.236546
# 1            26                  Lasso  157.775520  102.145127
# 2            26          BayesianRidge  157.818960  102.091509
# 3            26              LassoLars  169.291042  123.384916
# 4            26       LinearRegression  157.807838  102.237228
# 5            26  RandomForestRegressor  121.981909   59.849076
# 6            26  DecisionTreeRegressor  185.566940   81.655118
# 7            26           MLPRegressor  154.121465   90.691203
# 8            59                  Ridge  157.807596  102.236546
# 9            59                  Lasso  157.775520  102.145127
# 10           59          BayesianRidge  157.818960  102.091509
# 11           59              LassoLars  169.291042  123.384916
# 12           59       LinearRegression  157.807838  102.237228
# 13           59  RandomForestRegressor  121.981909   59.849076
# 14           59  DecisionTreeRegressor  188.270774   82.003550
# 15           59           MLPRegressor  154.121465   90.691203
# 16           77                  Ridge  157.807596  102.236546
# 17           77                  Lasso  157.775520  102.145127
# 18           77          BayesianRidge  157.818960  102.091509
# 19           77              LassoLars  169.291042  123.384916
# 20           77       LinearRegression  157.807838  102.237228
# 21           77  RandomForestRegressor  121.981909   59.849076
# 22           77  DecisionTreeRegressor  191.449673   84.932268
# 23           77           MLPRegressor  154.121465   90.691203
# 24           86                  Ridge  157.807596  102.236546
# 25           86                  Lasso  157.775520  102.145127
# 26           86          BayesianRidge  157.818960  102.091509
# 27           86              LassoLars  169.291042  123.384916
# 28           86       LinearRegression  157.807838  102.237228
# 29           86  RandomForestRegressor  121.981909   59.849076
# ..          ...                    ...         ...         ...
# 66          115          BayesianRidge  164.500877  110.674434
# 67          115              LassoLars  172.015062  126.098952
# 68          115       LinearRegression  164.078226  110.219737
# 69          115  RandomForestRegressor  132.062646   65.588875
# 70          115  DecisionTreeRegressor  179.508122   82.431249
# 71          115           MLPRegressor  143.235459   78.549677
# 72          160                  Ridge   87.535673   71.208390
# 73          160                  Lasso   87.484977   71.204674
# 74          160          BayesianRidge   88.908619   70.960523
# 75          160              LassoLars   88.405368   68.719770
# 76          160       LinearRegression   87.558594   71.196356
# 77          160  RandomForestRegressor   56.453695   33.663562
# 78          160  DecisionTreeRegressor  127.149011   41.556217
# 79          160           MLPRegressor  149.438220   98.111196
# 80          171                  Ridge  157.807596  102.236546
# 81          171                  Lasso  157.775520  102.145127
# 82          171          BayesianRidge  157.818960  102.091509
# 83          171              LassoLars  169.291042  123.384916
# 84          171       LinearRegression  157.807838  102.237228
# 85          171  RandomForestRegressor  121.981909   59.849076
# 86          171  DecisionTreeRegressor  188.014319   83.154841
# 87          171           MLPRegressor  154.121465   90.691203
# 88          187                  Ridge  157.807596  102.236546
# 89          187                  Lasso  157.775520  102.145127
# 90          187          BayesianRidge  157.818960  102.091509
# 91          187              LassoLars  169.291042  123.384916
# 92          187       LinearRegression  157.807838  102.237228
# 93          187  RandomForestRegressor  121.981909   59.849076
# 94          187  DecisionTreeRegressor  179.325972   79.889666
# 95          187           MLPRegressor  154.121465   90.691203
#
# [96 rows x 4 columns]

# %%
gb = final.groupby('alg')

# %%
N = 9
ind = range(N)
mean = list(gb['RMSE'].describe()['mean'])
mean.append(141.517)
std = list(gb['RMSE'].describe()['std'])
std.append(21.3441)

# %%
print(mean, std)
# Out:
# [155.6466811141064, 179.27062523053692, 155.46572681956789, 165.48748935550694, 155.49257923487031, 155.26119920542416, 119.18989546199481, 155.49051061437476, 141.517] [23.440991520739214, 17.100186345380038, 23.79326666813116, 25.996144816408886, 23.779444050008575, 9.4396759061028579, 20.853456280790219, 23.785352476493319, 21.3441]

# %%
p1 = plt.bar(ind, mean, 0.4, yerr=std)

plt.ylabel('GHI ($W/m^2$)')
plt.title('Prediction RMSE of different models')
plt.xlabel('Model')
plt.xticks(ind, ('BR', 'DT', 'Lasso', 'LasLar', 'LR', 'MLP', 'RF', 'Ridge', 'LSTM'))
# plt.yticks(np.arange(50, 2))
plt.axhline(y=gb['RMSE'].describe()['mean']['RandomForestRegressor'], linewidth=0.15)
plt.savefig('ghi.png')
